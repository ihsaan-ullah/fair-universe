# %% [markdown]
# # FAIR UNIVERSE Toy Dataset
#
# GitHub Repo: https://github.com/ihsaan-ullah/fair-universe
# ***

# %% [markdown]
# ### import data generator

# %%
from data_generator import DataGenerator

# %% [markdown]
# ### initialize data generator instance

# %%
data_gen = DataGenerator()

# %% [markdown]
# ### load settings from JSON

# %%
data_gen.load_settings()
# Out:
# -----------------------------------
# [+] Settings JSON File Loaded!
# -----------------------------------

# %% [markdown]
# ### load distributions from settings

# %%
data_gen.load_distributions()
# Out:
# -----------------------------------
# [+] Distributions Loaded!
# -----------------------------------

# %% [markdown]
# ### load systematics from settings

# %%
data_gen.load_systematics()
# Out:
# -----------------------------------
# [+] Systematics Loaded!
# -----------------------------------

# %% [markdown]
# ### generate data using distributions and systematics

# %%
data_gen.generate_data(apply_systematics=True)
# Out:
# -----------------------------------
# [+] Data Generated!
# -----------------------------------
# -----------------------------------
# [+] Systemtics Applied!
# -----------------------------------

# %% [markdown]
# ### get data as a dataframe

# %%
df = data_gen.get_data()

# %% [markdown]
# ### show statistics of data

# %%
data_gen.show_statistics()
# Out:
# #===============================#
# # Data Statistics
# #===============================#
# Signal datapoints : 1000
# Background datapoints : 1000
# ---------------
# Total  datapoints : 2000
# ---------------
# Total Classes =  2
# Signal label : 1
# Background label : 0
# ---------------

# %% [markdown]
# ### show distribution parameters

# %%
data_gen.show_distribution_parameters()
# Out:
# #===============================#
# # Distribution Parameters
# #===============================#
# Signal Distribution :
# {'name': 'Gaussian', 'mu': [1, 3], 'sigma': [0.8, 1.2]}
# ---------------
# Background Distribution :
# {'name': 'Exponential', 'lambda': [2, 1]}
# ---------------

# %% [markdown]
# ### show distribution parameters

# %%
data_gen.show_systematics_parameters()
# Out:
# #===============================#
# # Systematics Parameters
# #===============================#
# {'name': 'Scaling', 'allowed_dimension': -1, 'scaling_vector': [1, 1]}
# ---------------

# %% [markdown]
# ### visualize data

# %%
data_gen.visualize_data()

# %% [markdown]
# ### visualize data distribution (1D histogram)

# %%
data_gen.visualize_distributions_1d()

# %% [markdown]
# ### visualize data distribution (2D histogram)

# %%
data_gen.visualize_distributions_2d()

# %% [markdown]
# ### save data as csv

# %%
data_gen.save_data()
# Out:
# -----------------------------------
# [+] Data Saved as CSV in fair-universe-data.csv
# -----------------------------------
