# %% [markdown]
# TESTING SYSTEMATICS

# %%
from systematics import Systematics
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import sys
from ingestion import Ingestion

# %%
# Init Ingestion
ingestion = Ingestion()

# Start timer
ingestion.start_timer()

# load test set
ingestion.load_train_set()

# load test set
ingestion.load_test_sets()
# Out:
# [*] Loading Train data
# [*] Loading Test data

# %%
data = (ingestion.train_set['data'])

weights = np.array((ingestion.train_set['weights']))
target = np.array((ingestion.train_set['labels']))

# %%
plt.figure()
nbins = 50
ax=data[target==0].hist(weights=weights[target==0],figsize=(15,12),color='b',alpha=0.5,density=True, bins = nbins,label="B")
ax=ax.flatten()[:data.shape[1]] # to avoid error if holes in the grid of plots (like if 7 or 8 features)
data[target==1].hist(weights=weights[target==1],figsize=(15,12),color='r',alpha=0.5,density=True,ax=ax, bins = nbins,label="S")


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_syst = data.copy()

data_syst = Systematics(
    data=data_syst,
    tes=1.3
    ).data
# Out:
# Tau energy rescaling : 1.3

# %%
plt.figure()
nbins = 50
ax=data_syst[target==0].hist(weights=weights[target==0],figsize=(15,12),color='b',alpha=0.5,density=True, bins = nbins,label="B")
ax=ax.flatten()[:data.shape[1]] # to avoid error if holes in the grid of plots (like if 7 or 8 features)
data_syst[target==1].hist(weights=weights[target==1],figsize=(15,12),color='r',alpha=0.5,density=True,ax=ax, bins = nbins,label="S")


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_diff = data - data_syst

# %%
plt.figure()
nbins = 50
ax=data_diff[target==0].hist(weights=weights[target==0],figsize=(15,12),color='b',alpha=0.5,density=True, bins = nbins,label="B")
ax=ax.flatten()[:data.shape[1]] # to avoid error if holes in the grid of plots (like if 7 or 8 features)
data_diff[target==1].hist(weights=weights[target==1],figsize=(15,12),color='r',alpha=0.5,density=True,ax=ax, bins = nbins,label="S")


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
